# %%
# Load Required Libraries
import pandas as pd

# Load tweet_metadata and tweets CSV Files
tweet_metadata = pd.read_csv('tweet_metadata.csv')
tweets = pd.read_csv('tweets.csv')

# Join DataFrames on "id" Column
# If either file uses a different column name for the tweet ID, adjust as needed
df = pd.merge(tweet_metadata, tweets, on='id', how='inner')

# Display the first few rows of the joined DataFrame
df.head()
# Out:
#                    id              countries_found currencies_found  \
# 0  115437112529618205                           []               []
# 1  115436984200406691  ['Canada', 'United States']   ['CAD', 'USD']
# 2  115436968622280698                           []               []
# 3  115436967550742005                           []               []
# 4  115436966353094571                           []               []
#
#    sentiment_compound  sentiment_positive  sentiment_negative  \
# 0              0.9682               0.249               0.031
# 1             -0.8935               0.086               0.107
# 2              0.0000               0.000               0.000
# 3              0.0000               0.000               0.000
# 4              0.0000               0.000               0.000
#
#    sentiment_neutral sentiment_label  page_number  browse_flag  ...  \
# 0              0.721        positive            1         True  ...
# 1              0.807        negative            1         True  ...
# 2              1.000         neutral            1         True  ...
# 3              1.000         neutral            1         True  ...
# 4              1.000         neutral            1         True  ...
#
#                                 account_url           handle      platform  \
# 0  https://truthsocial.com/@realDonaldTrump  realDonaldTrump  Truth Social
# 1  https://truthsocial.com/@realDonaldTrump  realDonaldTrump  Truth Social
# 2  https://truthsocial.com/@realDonaldTrump  realDonaldTrump  Truth Social
# 3  https://truthsocial.com/@realDonaldTrump  realDonaldTrump  Truth Social
# 4  https://truthsocial.com/@realDonaldTrump  realDonaldTrump  Truth Social
#
#                                             post_url    social_author  \
# 0  https://truthsocial.com/@realDonaldTrump/posts...  realDonaldTrump
# 1  https://truthsocial.com/@realDonaldTrump/posts...  realDonaldTrump
# 2  https://truthsocial.com/@realDonaldTrump/posts...  realDonaldTrump
# 3  https://truthsocial.com/@realDonaldTrump/posts...  realDonaldTrump
# 4  https://truthsocial.com/@realDonaldTrump/posts...  realDonaldTrump
#
#   social_favorite_count social_repost_count social_visibility  \
# 0                     3                   0            public
# 1                  7012                2015            public
# 2                    62                  21            public
# 3                    60                  21            public
# 4                    15                   4            public
#
#             search_id score
# 0  115437112529618205   NaN
# 1  115436984200406691   NaN
# 2  115436968622280698   NaN
# 3  115436967550742005   NaN
# 4  115436966353094571   NaN
#
# [5 rows x 32 columns]

# %%
# Load FX Calls and FX Puts datasets
fx_calls = pd.read_csv('fx_calls.csv')
fx_puts = pd.read_csv('fx_puts.csv')

# Display the first few rows of each DataFrame
print('FX Calls:')
display(fx_calls.head())
print('FX Puts:')
display(fx_puts.head())
# Out:
# FX Calls:
#                    OptionTicker Underlying OptionType   TradeDate  Expiration  \
# 0  INRUSD OPT 20251017 0.0113 C     INRUSD       Call  2025-10-12  2025-10-17
# 1  INRUSD OPT 20251017 0.0113 C     INRUSD       Call  2025-10-12  2025-10-17
# 2    JPYUSD OPT 20251010 0.01 C     JPYUSD       Call  2025-10-06  2025-10-10
# 3  INRUSD OPT 20250912 0.0113 C     INRUSD       Call  2025-09-09  2025-09-12
# 4  GBPUSD OPT 20250822 1.3508 C     GBPUSD       Call  2025-08-18  2025-08-22
#
#    Strike      Spot       Bid       Ask       Mid  ImpliedVol  Delta  \
# 0  0.0113  0.011267  0.000090  0.000100  0.000095        0.18    0.5
# 1  0.0113  0.011267  0.000090  0.000100  0.000095        0.18    0.5
# 2  0.0100  0.006652  0.000021  0.000023  0.000022        0.08    0.5
# 3  0.0113  0.011336  0.000070  0.000078  0.000074        0.18    0.5
# 4  1.3508  1.350822  0.005374  0.005939  0.005656        0.10    0.5
#
#    Notional Currency
# 0    100000      USD
# 1    100000      USD
# 2    100000      USD
# 3    100000      USD
# 4    100000      USD
# FX Puts:
#                    OptionTicker Underlying OptionType   TradeDate  Expiration  \
# 0  INRUSD OPT 20251017 0.0113 P     INRUSD        Put  2025-10-12  2025-10-17
# 1  INRUSD OPT 20251017 0.0113 P     INRUSD        Put  2025-10-12  2025-10-17
# 2    JPYUSD OPT 20251010 0.01 P     JPYUSD        Put  2025-10-06  2025-10-10
# 3  INRUSD OPT 20250912 0.0113 P     INRUSD        Put  2025-09-09  2025-09-12
# 4  GBPUSD OPT 20250822 1.3508 P     GBPUSD        Put  2025-08-18  2025-08-22
#
#    Strike      Spot       Bid       Ask       Mid  ImpliedVol  Delta  \
# 0  0.0113  0.011267  0.000090  0.000100  0.000095        0.18   -0.5
# 1  0.0113  0.011267  0.000090  0.000100  0.000095        0.18   -0.5
# 2  0.0100  0.006652  0.000021  0.000023  0.000022        0.08   -0.5
# 3  0.0113  0.011336  0.000070  0.000078  0.000074        0.18   -0.5
# 4  1.3508  1.350822  0.005374  0.005939  0.005656        0.10   -0.5
#
#    Notional Currency
# 0    100000      USD
# 1    100000      USD
# 2    100000      USD
# 3    100000      USD
# 4    100000      USD

# %%
# Filter tweets: adjusted sentiment thresholds and specific currencies (CAD, INR, JPY, GBP)
# Fix: properly handle currencies_found stored as string representations of lists (e.g., "['JPY','USD']")
# Criteria:
#  - sentiment_compound > 0.75 (strong positive)
#    OR sentiment_compound < -0.75 (strong negative)
#  - currencies_found (parsed) contains any of target currencies

target_currencies = {'CAD','INR','JPY','GBP'}

import ast

# Ensure required columns exist
missing_cols = [col for col in ['sentiment_compound','currencies_found'] if col not in df.columns]
if missing_cols:
    print(f"Warning: Missing columns in df: {missing_cols}. Attempting to proceed with available data.")

# Normalize currencies_found to list
def normalize_currencies(val):
    if isinstance(val, list):
        return val
    if pd.isna(val):
        return []
    if isinstance(val, str):
        s = val.strip()
        # Attempt to parse list-like string
        if s.startswith('[') and s.endswith(']'):
            try:
                parsed = ast.literal_eval(s)
                if isinstance(parsed, list):
                    return [str(x).strip().upper() for x in parsed]
            except Exception:
                pass
        # Fallback: split by commas
        return [piece.strip().upper() for piece in s.split(',') if piece.strip()]
    return []

if 'currencies_found' in df.columns:
    norm_col = df['currencies_found'].apply(normalize_currencies)
else:
    norm_col = pd.Series([[]]*len(df))

# Helper to check currency presence
def has_target_currency_list(lst):
    return any(cur in target_currencies for cur in lst)

if 'sentiment_compound' in df.columns:
    sentiment_mask = (df['sentiment_compound'] > 0.75) | (df['sentiment_compound'] < -0.75)
else:
    sentiment_mask = pd.Series([False]*len(df))

currency_mask = norm_col.apply(has_target_currency_list)

filtered_df = df[sentiment_mask & currency_mask].copy()
filtered_df['normalized_currencies'] = norm_col[sentiment_mask & currency_mask]

print(f"Total tweets: {len(df)}")
print(f"Tweets with sentiment >0.75 or < -0.75 mentioning target currencies: {len(filtered_df)}")

# Debug: strong positive JPY candidates
if 'sentiment_compound' in df.columns:
    debug_candidates = df[(df['sentiment_compound'] > 0.75) & norm_col.apply(lambda L: 'JPY' in L)]
    if len(debug_candidates) > 0:
        print(f"Strong positive JPY candidates total: {len(debug_candidates)}")

# Show sample rows
if len(filtered_df) > 0:
    show_cols = []
    for c in ['id','tweet_id','date','text','sentiment_compound','currencies_found','normalized_currencies']:
        if c in filtered_df.columns:
            show_cols.append(c)
    display(filtered_df.head(20)[show_cols])
else:
    print("No records matched the >0.75/<-0.75 sentiment criteria with target currencies.")
# Out:
# Total tweets: 7242
# Tweets with sentiment >0.75 or < -0.75 mentioning target currencies: 77
# Strong positive JPY candidates total: 10
#                       id                       date  \
# 1     115436984200406691  2025-10-25 21:43:11+00:00
# 8     115436697060819133  2025-10-25 20:30:10+00:00
# 47    115428874684902595  2025-10-24 11:20:50+00:00
# 49    115426967566430347  2025-10-24 03:15:50+00:00
# 51    115426823727952497  2025-10-24 02:39:15+00:00
# 193   115361112506916753  2025-10-12 12:08:01+00:00
# 196   115359298785234325  2025-10-12 04:26:46+00:00
# 305   115327555965429625  2025-10-06 13:54:09+00:00
# 685   115176472700835865  2025-09-09 21:31:41+00:00
# 807   115129261076571259  2025-09-01 13:25:09+00:00
# 888   115114745146658004  2025-08-29 23:53:34+00:00
# 971   115074344428193585  2025-08-22 20:39:08+00:00
# 1059  115052030103944534  2025-08-18 22:04:18+00:00
# 1261  114994974199724855  2025-08-08 20:14:14+00:00
# 1273  114990543084538507  2025-08-08 01:27:21+00:00
# 1334  114970981123138842  2025-08-04 14:32:29+00:00
# 1351  114963263700328714  2025-08-03 05:49:50+00:00
# 1436  114945847973193713  2025-07-31 04:00:47+00:00
# 1440  114943927434273211  2025-07-30 19:52:22+00:00
# 1445  114942106248731470  2025-07-30 12:09:13+00:00
#
#                                                    text  sentiment_compound  \
# 1     RT @realDonaldTrump Canada was caught, red han...             -0.8935
# 8     Canada was caught, red handed, putting up a fr...             -0.8935
# 47    CANADA CHEATED AND GOT CAUGHT!!!They fraudulen...              0.8690
# 49    The Ronald Reagan Foundation has just announce...              0.8547
# 51    The Ronald Reagan Foundation has just announce...              0.8547
# 193   RT @realDonaldTrump I am pleased to announce t...              0.9734
# 196   I am pleased to announce that the great Dan Sc...              0.9734
# 305   Japan has just elected its first female Prime ...              0.9600
# 685   I am pleased to announce that India, and the U...              0.9588
# 807   What few people understand is that we do very ...             -0.9196
# 888   RT @marklevinshow THE APPELLATE COURT MAJORITY...              0.8160
# 971   I am pleased to announce that I am promoting S...              0.9928
# 1059  I had a very good meeting with distinguished g...              0.9770
# 1261  As President, my highest aspiration is to brin...              0.8750
# 1273  Melania is GREAT!!! https://www. dailymail.co....              0.7723
# 1334  Elizabeth Warren is a LOSER! She lies about ev...             -0.8027
# 1351  The very wonderful and talented Lara Trump, wh...             -0.9408
# 1436  I don’t care what India does with Russia. They...             -0.7777
# 1440  We are very busy in the White House today work...              0.9685
# 1445  Remember, while India is our friend, we have, ...             -0.8589
#
#                                 currencies_found  \
# 1                                 ['CAD', 'USD']
# 8                                 ['CAD', 'USD']
# 47                                ['CAD', 'USD']
# 49                                       ['CAD']
# 51                                       ['CAD']
# 193                                      ['INR']
# 196                                      ['INR']
# 305                                      ['JPY']
# 685                               ['INR', 'USD']
# 807                        ['INR', 'RUB', 'USD']
# 888                        ['MXN', 'CNY', 'CAD']
# 971                               ['INR', 'USD']
# 1059  ['EUR', 'EUR', 'GBP', 'EUR', 'RUB', 'USD']
# 1261                                     ['INR']
# 1273                                     ['GBP']
# 1334                                     ['INR']
# 1351                                     ['INR']
# 1436                       ['INR', 'RUB', 'USD']
# 1440                       ['INR', 'KRW', 'USD']
# 1445                       ['CNY', 'RUB', 'INR']
#
#                normalized_currencies
# 1                         [CAD, USD]
# 8                         [CAD, USD]
# 47                        [CAD, USD]
# 49                             [CAD]
# 51                             [CAD]
# 193                            [INR]
# 196                            [INR]
# 305                            [JPY]
# 685                       [INR, USD]
# 807                  [INR, RUB, USD]
# 888                  [MXN, CNY, CAD]
# 971                       [INR, USD]
# 1059  [EUR, EUR, GBP, EUR, RUB, USD]
# 1261                           [INR]
# 1273                           [GBP]
# 1334                           [INR]
# 1351                           [INR]
# 1436                 [INR, RUB, USD]
# 1440                 [INR, KRW, USD]
# 1445                 [CNY, RUB, INR]

# %%
# Create mover_tweets dataframe from filtered results
mover_tweets = filtered_df.copy()
print(f"mover_tweets created with {len(mover_tweets)} rows.")

# Basic per-currency breakdown
if len(mover_tweets) > 0 and 'normalized_currencies' in mover_tweets.columns:
    from collections import Counter
    flat = [cur for lst in mover_tweets['normalized_currencies'] for cur in lst if cur in target_currencies]
    freq = Counter(flat)
    print("Per target currency counts:")
    for cur, cnt in freq.items():
        print(f"  {cur}: {cnt}")

# Show a concise sample
sample_cols = [c for c in ['id','tweet_id','date','text','sentiment_compound','normalized_currencies'] if c in mover_tweets.columns]
if sample_cols:
    display(mover_tweets.head(10)[sample_cols])
# Out:
# mover_tweets created with 77 rows.
# Per target currency counts:
#   CAD: 35
#   INR: 19
#   JPY: 11
#   GBP: 12
#                      id                       date  \
# 1    115436984200406691  2025-10-25 21:43:11+00:00
# 8    115436697060819133  2025-10-25 20:30:10+00:00
# 47   115428874684902595  2025-10-24 11:20:50+00:00
# 49   115426967566430347  2025-10-24 03:15:50+00:00
# 51   115426823727952497  2025-10-24 02:39:15+00:00
# 193  115361112506916753  2025-10-12 12:08:01+00:00
# 196  115359298785234325  2025-10-12 04:26:46+00:00
# 305  115327555965429625  2025-10-06 13:54:09+00:00
# 685  115176472700835865  2025-09-09 21:31:41+00:00
# 807  115129261076571259  2025-09-01 13:25:09+00:00
#
#                                                   text  sentiment_compound  \
# 1    RT @realDonaldTrump Canada was caught, red han...             -0.8935
# 8    Canada was caught, red handed, putting up a fr...             -0.8935
# 47   CANADA CHEATED AND GOT CAUGHT!!!They fraudulen...              0.8690
# 49   The Ronald Reagan Foundation has just announce...              0.8547
# 51   The Ronald Reagan Foundation has just announce...              0.8547
# 193  RT @realDonaldTrump I am pleased to announce t...              0.9734
# 196  I am pleased to announce that the great Dan Sc...              0.9734
# 305  Japan has just elected its first female Prime ...              0.9600
# 685  I am pleased to announce that India, and the U...              0.9588
# 807  What few people understand is that we do very ...             -0.9196
#
#     normalized_currencies
# 1              [CAD, USD]
# 8              [CAD, USD]
# 47             [CAD, USD]
# 49                  [CAD]
# 51                  [CAD]
# 193                 [INR]
# 196                 [INR]
# 305                 [JPY]
# 685            [INR, USD]
# 807       [INR, RUB, USD]

# %%
# Long Straddle Backtest (simplified): fixed premium 0.002 per leg, forward-filled FX rates.
# Spot lookup now uses the nearest prior available FX rate if the exact tweet day is missing (unbounded backward search).
import os, math, datetime as dt
import pandas as pd

FIXED_PREMIUM_PER_LEG = 0.001
FILL_MISSING_RATES = True

# Column candidate mappings
col_candidates = {
    'date': ['TradeDate','Date','trade_date','listing_date'],
    'expiry': ['Expiration','Expiry','expiration','expiry_date','maturity'],
    'underlying': ['Underlying','underlying','Currency','symbol'],
    'strike': ['Strike','strike','StrikePrice'],
    'bid': ['Bid','bid'],
    'ask': ['Ask','ask'],
    'mid': ['Mid','mid','Price','premium']
}

def map_columns(df, label):
    mapping = {}
    lower = {c.lower(): c for c in df.columns}
    for key, cands in col_candidates.items():
        for cand in cands:
            if cand.lower() in lower:
                mapping[key] = lower[cand.lower()]
                break
    missing = [k for k in ['date','expiry','underlying','strike'] if k not in mapping]
    if missing:
        print(f"Warning: {label} missing columns needed for selection: {missing}")
    return mapping

calls_map = map_columns(fx_calls, 'fx_calls')
puts_map  = map_columns(fx_puts,  'fx_puts')

# Parse dates
for mp, df_opts in [(calls_map, fx_calls),(puts_map, fx_puts)]:
    if 'date' in mp:
        df_opts[mp['date']] = pd.to_datetime(df_opts[mp['date']], errors='coerce', utc=True).dt.tz_localize(None)
    if 'expiry' in mp:
        df_opts[mp['expiry']] = pd.to_datetime(df_opts[mp['expiry']], errors='coerce', utc=True).dt.tz_localize(None)

exchange_dir = 'exchange_rates'
rate_cache = {}
rate_col_cache = {}

def load_rates(cur):
    if cur in rate_cache:
        return rate_cache[cur]
    path = os.path.join(exchange_dir, f"{cur}_USD_rates.csv")
    if not os.path.exists(path):
        print(f"Rate file missing for {cur}: {path}")
        rate_cache[cur] = None
        return None
    df_r = pd.read_csv(path)
    date_col = None
    for c in df_r.columns:
        if c.lower() in ('date','day') or 'date' in c.lower():
            date_col = c; break
    if date_col is None:
        date_col = df_r.columns[0]
    df_r[date_col] = pd.to_datetime(df_r[date_col], errors='coerce', utc=True).dt.tz_localize(None)
    rate_col = None
    for c in df_r.columns:
        if c == date_col: continue
        if pd.api.types.is_numeric_dtype(df_r[c]):
            rate_col = c; break
    if rate_col is None:
        print(f"No numeric rate column found in {path}; skipping {cur}")
        rate_cache[cur] = None
        return None
    df_r = df_r.dropna(subset=[date_col, rate_col]).sort_values(date_col)
    if FILL_MISSING_RATES and not df_r.empty:
        full_idx = pd.date_range(df_r[date_col].min(), df_r[date_col].max(), freq='D')
        df_r = df_r.set_index(date_col).reindex(full_idx).rename_axis(date_col)
        df_r[rate_col] = df_r[rate_col].ffill()
        df_r = df_r.reset_index().rename(columns={'index': date_col})
    rate_cache[cur] = df_r
    rate_col_cache[cur] = (date_col, rate_col)
    return df_r

def get_spot(cur, d):
    """Return spot for date d; if missing, return the most recent prior available rate (no fixed lookback limit)."""
    df_r = load_rates(cur)
    if df_r is None: return None
    date_col, rate_col = rate_col_cache[cur]
    target_date = pd.to_datetime(d).normalize()
    # Exact match
    row_exact = df_r[df_r[date_col] == target_date]
    if not row_exact.empty:
        return float(row_exact.iloc[0][rate_col])
    # Prior dates
    prior = df_r[df_r[date_col] < target_date]
    if prior.empty:
        return None
    return float(prior.iloc[-1][rate_col])

def week_expiry(date):
    date = pd.to_datetime(date).normalize()
    for i in range(7):
        cand = date + pd.Timedelta(days=i)
        if cand.weekday() == 4:
            return cand
    return None

def extract_ccy(underlying):
    if not isinstance(underlying, str) or len(underlying) < 3:
        return None
    return underlying[:3].upper()

def select_atm(df_opts, mapping, cur, expiry, spot):
    if not all(k in mapping for k in ['underlying','expiry','strike']):
        return None
    sub = df_opts[(df_opts[mapping['expiry']] == expiry)].copy()
    if sub.empty:
        return None
    sub['__ccy'] = sub[mapping['underlying']].apply(extract_ccy)
    sub = sub[sub['__ccy'] == cur]
    if sub.empty:
        return None
    sub[mapping['strike']] = pd.to_numeric(sub[mapping['strike']], errors='coerce')
    sub = sub.dropna(subset=[mapping['strike']])
    if sub.empty:
        return None
    sub['atm_dist'] = (sub[mapping['strike']] - spot).abs()
    return sub.sort_values('atm_dist').iloc[0]

trade_rows = []

if 'mover_tweets' not in globals():
    print("mover_tweets not defined; run previous cell.")
else:
    tweet_date_col = 'date' if 'date' in mover_tweets.columns else None
    if tweet_date_col is None:
        print("No 'date' column in mover_tweets; cannot proceed.")
    else:
        mover_tweets[tweet_date_col] = pd.to_datetime(mover_tweets[tweet_date_col], errors='coerce').dt.tz_localize(None)
        for idx, row in mover_tweets.iterrows():
            base_date = row[tweet_date_col]
            if pd.isna(base_date):
                continue
            if isinstance(row.get('normalized_currencies'), list):
                currencies = [c for c in row['normalized_currencies'] if c in target_currencies]
            elif isinstance(row.get('currencies_found'), list):
                currencies = [c for c in row['currencies_found'] if c in target_currencies]
            else:
                currencies = []
            for cur in currencies:
                expiry = week_expiry(base_date)
                if expiry is None or (expiry - base_date).days > 7:
                    continue
                spot_entry = get_spot(cur, base_date)
                if spot_entry is None:
                    continue
                call_row = select_atm(fx_calls, calls_map, cur, expiry, spot_entry)
                put_row  = select_atm(fx_puts,  puts_map,  cur, expiry, spot_entry)
                if call_row is None or put_row is None:
                    continue
                strike_call = float(call_row[calls_map['strike']]) if 'strike' in calls_map else spot_entry
                strike_put  = float(put_row[puts_map['strike']]) if 'strike' in puts_map else spot_entry
                spot_expiry = get_spot(cur, expiry)
                if spot_expiry is None:
                    continue
                payoff = max(spot_expiry - strike_call, 0) + max(strike_put - spot_expiry, 0)
                trade_rows.append({
                    'tweet_id': row.get('id', row.get('tweet_id', idx)),
                    'currency': cur,
                    'tweet_date': base_date.normalize(),
                    'expiry': expiry,
                    'spot_entry': spot_entry,
                    'spot_expiry': spot_expiry,
                    'strike_call': strike_call,
                    'strike_put': strike_put,
                    'premium_call': FIXED_PREMIUM_PER_LEG,
                    'premium_put': FIXED_PREMIUM_PER_LEG,
                    'total_cost': 2*FIXED_PREMIUM_PER_LEG,
                    'payoff': payoff,
                    'return_pct': (payoff - 2*FIXED_PREMIUM_PER_LEG)/(2*FIXED_PREMIUM_PER_LEG) if 2*FIXED_PREMIUM_PER_LEG>0 else None,
                    'sentiment_compound': row.get('sentiment_compound'),
                    'tweet_text': (row.get('text','')[:120] + '...') if isinstance(row.get('text'), str) and len(row.get('text'))>120 else row.get('text')
                })

trades_df = pd.DataFrame(trade_rows)
print(f"Constructed {len(trades_df)} straddle trades (fixed premium {FIXED_PREMIUM_PER_LEG} per leg).")

if not trades_df.empty:
    print("Summary (by currency):")
    print(trades_df.groupby('currency')['return_pct'].agg(['count','mean','median']).round(4))
    print(f"\nOverall avg return: {trades_df['return_pct'].mean():.4%}")
    display(trades_df.head(20))
    trades_df.to_csv('long_straddle_backtest.csv', index=False)
    print("Saved long_straddle_backtest.csv")
else:
    print("No trades generated - still missing alignment or rate coverage causing spot/option selection skips.")
# Out:
# Constructed 68 straddle trades (fixed premium 0.001 per leg).
# Summary (by currency):
#           count    mean  median
# currency
# CAD          31 -0.4844 -0.9752
# GBP          10  0.2116 -0.9804
# INR          17 -0.9689 -0.9748
# JPY          10  0.6130  0.6412
#
# Overall avg return: -34.1795%
#               tweet_id currency tweet_date     expiry  spot_entry  \
# 0   115436984200406691      CAD 2025-10-25 2025-10-31    0.714970
# 1   115436697060819133      CAD 2025-10-25 2025-10-31    0.714970
# 2   115361112506916753      INR 2025-10-12 2025-10-17    0.011253
# 3   115359298785234325      INR 2025-10-12 2025-10-17    0.011253
# 4   115327555965429625      JPY 2025-10-06 2025-10-10    0.006684
# 5   115176472700835865      INR 2025-09-09 2025-09-12    0.011366
# 6   115129261076571259      INR 2025-09-01 2025-09-05    0.011341
# 7   115052030103944534      GBP 2025-08-18 2025-08-22    1.355638
# 8   114994974199724855      INR 2025-08-08 2025-08-08    0.011437
# 9   114970981123138842      INR 2025-08-04 2025-08-08    0.011462
# 10  114963263700328714      INR 2025-08-03 2025-08-08    0.011430
# 11  114945847973193713      INR 2025-07-31 2025-08-01    0.011401
# 12  114943927434273211      INR 2025-07-30 2025-08-01    0.011486
# 13  114942106248731470      INR 2025-07-30 2025-08-01    0.011486
# 14  114939759564715119      JPY 2025-07-30 2025-08-01    0.006737
# 15  114920242180121128      INR 2025-07-26 2025-08-01    0.011570
# 16  114899417740854572      JPY 2025-07-22 2025-07-25    0.006784
# 17  114885987478070699      INR 2025-07-20 2025-07-25    0.011622
# 18  114773601644828833      JPY 2025-06-30 2025-07-04    0.006920
# 19  114717932061341718      INR 2025-06-20 2025-06-20    0.011550
#
#     spot_expiry  strike_call  strike_put  premium_call  premium_put  \
# 0      0.714970       0.7150      0.7150         0.001        0.001
# 1      0.714970       0.7150      0.7150         0.001        0.001
# 2      0.011365       0.0113      0.0113         0.001        0.001
# 3      0.011365       0.0113      0.0113         0.001        0.001
# 4      0.006537       0.0100      0.0100         0.001        0.001
# 5      0.011329       0.0113      0.0113         0.001        0.001
# 6      0.011339       0.0114      0.0114         0.001        0.001
# 7      1.341940       1.3508      1.3508         0.001        0.001
# 8      0.011437       0.0114      0.0114         0.001        0.001
# 9      0.011437       0.0115      0.0115         0.001        0.001
# 10     0.011437       0.0114      0.0114         0.001        0.001
# 11     0.011430       0.0114      0.0114         0.001        0.001
# 12     0.011430       0.0114      0.0114         0.001        0.001
# 13     0.011430       0.0114      0.0114         0.001        0.001
# 14     0.006633       0.0100      0.0100         0.001        0.001
# 15     0.011430       0.0116      0.0116         0.001        0.001
# 16     0.006802       0.0100      0.0100         0.001        0.001
# 17     0.011570       0.0116      0.0116         0.001        0.001
# 18     0.006912       0.0100      0.0100         0.001        0.001
# 19     0.011550       0.0116      0.0116         0.001        0.001
#
#     total_cost    payoff  return_pct  sentiment_compound  \
# 0        0.002  0.000030   -0.985026             -0.8935
# 1        0.002  0.000030   -0.985026             -0.8935
# 2        0.002  0.000065   -0.967581              0.9734
# 3        0.002  0.000065   -0.967581              0.9734
# 4        0.002  0.003463    0.731278              0.9600
# 5        0.002  0.000029   -0.985407              0.9588
# 6        0.002  0.000061   -0.969390             -0.9196
# 7        0.002  0.008860    3.430216              0.9770
# 8        0.002  0.000037   -0.981348              0.8750
# 9        0.002  0.000063   -0.968652             -0.8027
# 10       0.002  0.000037   -0.981348             -0.9408
# 11       0.002  0.000030   -0.985022             -0.7777
# 12       0.002  0.000030   -0.985022              0.9685
# 13       0.002  0.000030   -0.985022             -0.8589
# 14       0.002  0.003367    0.683734              0.8924
# 15       0.002  0.000170   -0.914978             -0.9804
# 16       0.002  0.003198    0.598755              0.9753
# 17       0.002  0.000030   -0.985008              0.8904
# 18       0.002  0.003088    0.544145              0.9460
# 19       0.002  0.000050   -0.974752              0.9561
#
#                                            tweet_text
# 0   RT @realDonaldTrump Canada was caught, red han...
# 1   Canada was caught, red handed, putting up a fr...
# 2   RT @realDonaldTrump I am pleased to announce t...
# 3   I am pleased to announce that the great Dan Sc...
# 4   Japan has just elected its first female Prime ...
# 5   I am pleased to announce that India, and the U...
# 6   What few people understand is that we do very ...
# 7   I had a very good meeting with distinguished g...
# 8   As President, my highest aspiration is to brin...
# 9   Elizabeth Warren is a LOSER! She lies about ev...
# 10  The very wonderful and talented Lara Trump, wh...
# 11  I don’t care what India does with Russia. They...
# 12  We are very busy in the White House today work...
# 13  Remember, while India is our friend, we have, ...
# 14  Due to a massive earthquake that occurred in t...
# 15  Just spoke to the Prime Minister of Cambodia r...
# 16  We just completed a massive Deal with Japan, p...
# 17  The Washington “Whatever’s” should IMMEDIATELY...
# 18  To show people how spoiled Countries have beco...
# 19  I am very happy to report that I have arranged...
# Saved long_straddle_backtest.csv
